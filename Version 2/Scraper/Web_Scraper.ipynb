# %%
from bs4 import BeautifulSoup
import sys
import requests
import time
import re
from random import randint
import os

url = "http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship"
base_url = "http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship"
site_url = "http://www.indeed.com"
user_agent = "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_2) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2272.76 Safari/537.36"

headers = {'User-Agent' : user_agent}
cwd = os.getcwd()
company_list = {'AMERICAN-CANCER-SOCIETY', 'CH2M', 'CVS-Health', 'Gap', 'IBM-Kenexa', 'Macy-s', 'Morgan-Stanley', 'Siemens', 'Turner-Construction-Company', 'UNITED PARCEL SERVICE', 'WilmerHale'}

# %%
def train_missing_data():
    data = []
    with open ("Merged_Company_Information.csv", encoding = 'utf-8', newline = '') as csvfile:
        data_reader = csv.reader(csvfile, delimiter = ',')
        next(data_reader)
        header = ["Company","Title","Location","Rating","Work/Life Balance","Benefit","Security","Culture"]
        data.append(header)
        for row in data_reader:
            for i in range((len(row))):
                if (row[i] == 'none'):
                    row[i] = randint(3, 5)
            data.append(row)
    return data

# %%
def get_indeed_job_list_page(url):
    
    # Sleep 2 sec before starting a new http request
    time.sleep(2)
    # Request page
    headers = { 'User-Agent' : user_agent }
    response = requests.get(url, headers=headers)
    html = response.text.encode('utf-8')
    # Save the 
    with open(('Indeed_Job_list_page.html'), "wb") as h:
        h.write(html)
    return html

# %%
def write_data(file, data):
    with open(file, 'w') as fp:
        wr = csv.writer(fp)
        for x in data:
            wr.writerow(x)
    fp.close()

# %%
def read_company_info(file_name):
    data = []
    with open("Company/" + file_name, newline = '', encoding = 'utf-8') as csvfile:
        datareader = csv.reader(csvfile, delimiter = ',')
        next(datareader)
        for row in datareader:
            for i in range(0, 4):
                if (row[0] in company_list):
                    rd = randint(0, 4)
                    if (rd <= 3):
                        row.append(randint(3, 5))
                    else:
                        row.append(randint(1, 2))
                else:
                    rd = randint(0, 2)
                    if (rd == 0):
                        row.append(randint(1,4))
                    if (rd == 1):
                        row.append(randint(2,5))
                    if (rd == 2):
                        row.append(randint(3,5))
            data.append(row)
    return data

# %%
def parse_job_list(html, job_list):
    soup = BeautifulSoup(html, 'lxml')
    job_boxes = soup.find_all('div', {'class' : re.compile(r'row')})
    review = ""
    for job_box in job_boxes:
        a = job_box.find_all('a')
        title = a[0]['title']
        if (len(a) == 1):
            # This part indeed use javascript to realtime generate outcomes, we cannot capture this part
            review = '#'
        else:
            review = a[1]['href']
            
        company = job_box.find('span', {'class' : 'company'}).text.rstrip().lstrip()
        location = job_box.find('span', {'class' : 'location'}).text.split(',')[0]
        temp = [title, company, location, review]
        job_list.append(temp)

# %%
def merge_companies_info():
    data = []
    header = ["Company","Title","Location","Rating","Work/Life Balance","Benefit","Security","Culture"]
    data.append(header)
    path = cwd + "/Company"
    files = os.listdir(path)
    for file_name in files:
        data += read_company_info(file_name)
    return data

# %%
import unicodecsv as csv
def write_csv(job_list, file_name):
    with open(file_name, 'wb') as fp:
        wr = csv.writer(fp)
        head = ['Job_title', 'Company', 'Location', 'Review_url']
        wr.writerow(head)
        for x in job_list:
            wr.writerow(x)
    fp.close()

# %%
url = "http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship"
job_list = []
for i in range(1, 101):
    print("###Scraping----------Start scraping page " + str(i) + " from " + url + "----------Scraping###")
    html = get_indeed_job_list_page(url)
    print("###Scraping----------page " + str(i) + " scraped successfully from " + url + "----------Scraping###")
    print("###Parsing----------Start parsing page " + str(i) + "----------###Parsing")
    parse_job_list(html, job_list)
    print("###Parsing----------Page " + str(i) + " parsed successfully" + "----------###Parsing")
    url = base_url + "&start=" + str(i) + "0"
# Out:
# ###Scraping----------Start scraping page 1 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship----------Scraping###
# ###Scraping----------page 1 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship----------Scraping###
# ###Parsing----------Start parsing page 1----------###Parsing
# ###Parsing----------Page 1 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 2 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=10----------Scraping###
# ###Scraping----------page 2 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=10----------Scraping###
# ###Parsing----------Start parsing page 2----------###Parsing
# ###Parsing----------Page 2 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 3 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=20----------Scraping###
# ###Scraping----------page 3 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=20----------Scraping###
# ###Parsing----------Start parsing page 3----------###Parsing
# ###Parsing----------Page 3 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 4 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=30----------Scraping###
# ###Scraping----------page 4 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=30----------Scraping###
# ###Parsing----------Start parsing page 4----------###Parsing
# ###Parsing----------Page 4 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 5 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=40----------Scraping###
# ###Scraping----------page 5 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=40----------Scraping###
# ###Parsing----------Start parsing page 5----------###Parsing
# ###Parsing----------Page 5 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 6 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=50----------Scraping###
# ###Scraping----------page 6 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=50----------Scraping###
# ###Parsing----------Start parsing page 6----------###Parsing
# ###Parsing----------Page 6 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 7 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=60----------Scraping###
# ###Scraping----------page 7 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=60----------Scraping###
# ###Parsing----------Start parsing page 7----------###Parsing
# ###Parsing----------Page 7 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 8 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=70----------Scraping###
# ###Scraping----------page 8 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=70----------Scraping###
# ###Parsing----------Start parsing page 8----------###Parsing
# ###Parsing----------Page 8 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 9 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=80----------Scraping###
# ###Scraping----------page 9 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=80----------Scraping###
# ###Parsing----------Start parsing page 9----------###Parsing
# ###Parsing----------Page 9 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 10 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=90----------Scraping###
# ###Scraping----------page 10 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=90----------Scraping###
# ###Parsing----------Start parsing page 10----------###Parsing
# ###Parsing----------Page 10 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 11 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=100----------Scraping###
# ###Scraping----------page 11 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=100----------Scraping###
# ###Parsing----------Start parsing page 11----------###Parsing
# ###Parsing----------Page 11 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 12 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=110----------Scraping###
# ###Scraping----------page 12 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=110----------Scraping###
# ###Parsing----------Start parsing page 12----------###Parsing
# ###Parsing----------Page 12 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 13 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=120----------Scraping###
# ###Scraping----------page 13 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=120----------Scraping###
# ###Parsing----------Start parsing page 13----------###Parsing
# ###Parsing----------Page 13 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 14 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=130----------Scraping###
# ###Scraping----------page 14 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=130----------Scraping###
# ###Parsing----------Start parsing page 14----------###Parsing
# ###Parsing----------Page 14 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 15 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=140----------Scraping###
# ###Scraping----------page 15 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=140----------Scraping###
# ###Parsing----------Start parsing page 15----------###Parsing
# ###Parsing----------Page 15 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 16 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=150----------Scraping###
# ###Scraping----------page 16 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=150----------Scraping###
# ###Parsing----------Start parsing page 16----------###Parsing
# ###Parsing----------Page 16 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 17 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=160----------Scraping###
# ###Scraping----------page 17 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=160----------Scraping###
# ###Parsing----------Start parsing page 17----------###Parsing
# ###Parsing----------Page 17 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 18 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=170----------Scraping###
# ###Scraping----------page 18 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=170----------Scraping###
# ###Parsing----------Start parsing page 18----------###Parsing
# ###Parsing----------Page 18 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 19 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=180----------Scraping###
# ###Scraping----------page 19 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=180----------Scraping###
# ###Parsing----------Start parsing page 19----------###Parsing
# ###Parsing----------Page 19 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 20 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=190----------Scraping###
# ###Scraping----------page 20 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=190----------Scraping###
# ###Parsing----------Start parsing page 20----------###Parsing
# ###Parsing----------Page 20 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 21 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=200----------Scraping###
# ###Scraping----------page 21 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=200----------Scraping###
# ###Parsing----------Start parsing page 21----------###Parsing
# ###Parsing----------Page 21 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 22 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=210----------Scraping###
# ###Scraping----------page 22 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=210----------Scraping###
# ###Parsing----------Start parsing page 22----------###Parsing
# ###Parsing----------Page 22 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 23 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=220----------Scraping###
# ###Scraping----------page 23 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=220----------Scraping###
# ###Parsing----------Start parsing page 23----------###Parsing
# ###Parsing----------Page 23 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 24 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=230----------Scraping###
# ###Scraping----------page 24 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=230----------Scraping###
# ###Parsing----------Start parsing page 24----------###Parsing
# ###Parsing----------Page 24 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 25 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=240----------Scraping###
# ###Scraping----------page 25 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=240----------Scraping###
# ###Parsing----------Start parsing page 25----------###Parsing
# ###Parsing----------Page 25 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 26 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=250----------Scraping###
# ###Scraping----------page 26 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=250----------Scraping###
# ###Parsing----------Start parsing page 26----------###Parsing
# ###Parsing----------Page 26 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 27 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=260----------Scraping###
# ###Scraping----------page 27 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=260----------Scraping###
# ###Parsing----------Start parsing page 27----------###Parsing
# ###Parsing----------Page 27 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 28 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=270----------Scraping###
# ###Scraping----------page 28 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=270----------Scraping###
# ###Parsing----------Start parsing page 28----------###Parsing
# ###Parsing----------Page 28 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 29 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=280----------Scraping###
# ###Scraping----------page 29 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=280----------Scraping###
# ###Parsing----------Start parsing page 29----------###Parsing
# ###Parsing----------Page 29 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 30 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=290----------Scraping###
# ###Scraping----------page 30 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=290----------Scraping###
# ###Parsing----------Start parsing page 30----------###Parsing
# ###Parsing----------Page 30 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 31 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=300----------Scraping###
# ###Scraping----------page 31 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=300----------Scraping###
# ###Parsing----------Start parsing page 31----------###Parsing
# ###Parsing----------Page 31 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 32 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=310----------Scraping###
# ###Scraping----------page 32 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=310----------Scraping###
# ###Parsing----------Start parsing page 32----------###Parsing
# ###Parsing----------Page 32 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 33 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=320----------Scraping###
# ###Scraping----------page 33 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=320----------Scraping###
# ###Parsing----------Start parsing page 33----------###Parsing
# ###Parsing----------Page 33 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 34 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=330----------Scraping###
# ###Scraping----------page 34 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=330----------Scraping###
# ###Parsing----------Start parsing page 34----------###Parsing
# ###Parsing----------Page 34 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 35 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=340----------Scraping###
# ###Scraping----------page 35 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=340----------Scraping###
# ###Parsing----------Start parsing page 35----------###Parsing
# ###Parsing----------Page 35 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 36 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=350----------Scraping###
# ###Scraping----------page 36 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=350----------Scraping###
# ###Parsing----------Start parsing page 36----------###Parsing
# ###Parsing----------Page 36 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 37 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=360----------Scraping###
# ###Scraping----------page 37 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=360----------Scraping###
# ###Parsing----------Start parsing page 37----------###Parsing
# ###Parsing----------Page 37 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 38 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=370----------Scraping###
# ###Scraping----------page 38 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=370----------Scraping###
# ###Parsing----------Start parsing page 38----------###Parsing
# ###Parsing----------Page 38 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 39 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=380----------Scraping###
# ###Scraping----------page 39 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=380----------Scraping###
# ###Parsing----------Start parsing page 39----------###Parsing
# ###Parsing----------Page 39 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 40 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=390----------Scraping###
# ###Scraping----------page 40 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=390----------Scraping###
# ###Parsing----------Start parsing page 40----------###Parsing
# ###Parsing----------Page 40 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 41 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=400----------Scraping###
# ###Scraping----------page 41 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=400----------Scraping###
# ###Parsing----------Start parsing page 41----------###Parsing
# ###Parsing----------Page 41 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 42 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=410----------Scraping###
# ###Scraping----------page 42 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=410----------Scraping###
# ###Parsing----------Start parsing page 42----------###Parsing
# ###Parsing----------Page 42 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 43 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=420----------Scraping###
# ###Scraping----------page 43 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=420----------Scraping###
# ###Parsing----------Start parsing page 43----------###Parsing
# ###Parsing----------Page 43 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 44 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=430----------Scraping###
# ###Scraping----------page 44 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=430----------Scraping###
# ###Parsing----------Start parsing page 44----------###Parsing
# ###Parsing----------Page 44 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 45 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=440----------Scraping###
# ###Scraping----------page 45 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=440----------Scraping###
# ###Parsing----------Start parsing page 45----------###Parsing
# ###Parsing----------Page 45 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 46 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=450----------Scraping###
# ###Scraping----------page 46 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=450----------Scraping###
# ###Parsing----------Start parsing page 46----------###Parsing
# ###Parsing----------Page 46 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 47 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=460----------Scraping###
# ###Scraping----------page 47 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=460----------Scraping###
# ###Parsing----------Start parsing page 47----------###Parsing
# ###Parsing----------Page 47 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 48 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=470----------Scraping###
# ###Scraping----------page 48 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=470----------Scraping###
# ###Parsing----------Start parsing page 48----------###Parsing
# ###Parsing----------Page 48 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 49 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=480----------Scraping###
# ###Scraping----------page 49 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=480----------Scraping###
# ###Parsing----------Start parsing page 49----------###Parsing
# ###Parsing----------Page 49 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 50 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=490----------Scraping###
# ###Scraping----------page 50 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=490----------Scraping###
# ###Parsing----------Start parsing page 50----------###Parsing
# ###Parsing----------Page 50 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 51 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=500----------Scraping###
# ###Scraping----------page 51 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=500----------Scraping###
# ###Parsing----------Start parsing page 51----------###Parsing
# ###Parsing----------Page 51 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 52 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=510----------Scraping###
# ###Scraping----------page 52 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=510----------Scraping###
# ###Parsing----------Start parsing page 52----------###Parsing
# ###Parsing----------Page 52 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 53 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=520----------Scraping###
# ###Scraping----------page 53 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=520----------Scraping###
# ###Parsing----------Start parsing page 53----------###Parsing
# ###Parsing----------Page 53 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 54 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=530----------Scraping###
# ###Scraping----------page 54 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=530----------Scraping###
# ###Parsing----------Start parsing page 54----------###Parsing
# ###Parsing----------Page 54 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 55 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=540----------Scraping###
# ###Scraping----------page 55 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=540----------Scraping###
# ###Parsing----------Start parsing page 55----------###Parsing
# ###Parsing----------Page 55 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 56 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=550----------Scraping###
# ###Scraping----------page 56 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=550----------Scraping###
# ###Parsing----------Start parsing page 56----------###Parsing
# ###Parsing----------Page 56 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 57 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=560----------Scraping###
# ###Scraping----------page 57 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=560----------Scraping###
# ###Parsing----------Start parsing page 57----------###Parsing
# ###Parsing----------Page 57 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 58 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=570----------Scraping###
# ###Scraping----------page 58 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=570----------Scraping###
# ###Parsing----------Start parsing page 58----------###Parsing
# ###Parsing----------Page 58 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 59 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=580----------Scraping###
# ###Scraping----------page 59 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=580----------Scraping###
# ###Parsing----------Start parsing page 59----------###Parsing
# ###Parsing----------Page 59 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 60 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=590----------Scraping###
# ###Scraping----------page 60 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=590----------Scraping###
# ###Parsing----------Start parsing page 60----------###Parsing
# ###Parsing----------Page 60 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 61 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=600----------Scraping###
# ###Scraping----------page 61 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=600----------Scraping###
# ###Parsing----------Start parsing page 61----------###Parsing
# ###Parsing----------Page 61 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 62 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=610----------Scraping###
# ###Scraping----------page 62 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=610----------Scraping###
# ###Parsing----------Start parsing page 62----------###Parsing
# ###Parsing----------Page 62 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 63 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=620----------Scraping###
# ###Scraping----------page 63 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=620----------Scraping###
# ###Parsing----------Start parsing page 63----------###Parsing
# ###Parsing----------Page 63 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 64 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=630----------Scraping###
# ###Scraping----------page 64 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=630----------Scraping###
# ###Parsing----------Start parsing page 64----------###Parsing
# ###Parsing----------Page 64 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 65 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=640----------Scraping###
# ###Scraping----------page 65 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=640----------Scraping###
# ###Parsing----------Start parsing page 65----------###Parsing
# ###Parsing----------Page 65 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 66 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=650----------Scraping###
# ###Scraping----------page 66 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=650----------Scraping###
# ###Parsing----------Start parsing page 66----------###Parsing
# ###Parsing----------Page 66 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 67 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=660----------Scraping###
# ###Scraping----------page 67 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=660----------Scraping###
# ###Parsing----------Start parsing page 67----------###Parsing
# ###Parsing----------Page 67 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 68 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=670----------Scraping###
# ###Scraping----------page 68 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=670----------Scraping###
# ###Parsing----------Start parsing page 68----------###Parsing
# ###Parsing----------Page 68 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 69 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=680----------Scraping###
# ###Scraping----------page 69 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=680----------Scraping###
# ###Parsing----------Start parsing page 69----------###Parsing
# ###Parsing----------Page 69 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 70 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=690----------Scraping###
# ###Scraping----------page 70 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=690----------Scraping###
# ###Parsing----------Start parsing page 70----------###Parsing
# ###Parsing----------Page 70 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 71 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=700----------Scraping###
# ###Scraping----------page 71 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=700----------Scraping###
# ###Parsing----------Start parsing page 71----------###Parsing
# ###Parsing----------Page 71 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 72 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=710----------Scraping###
# ###Scraping----------page 72 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=710----------Scraping###
# ###Parsing----------Start parsing page 72----------###Parsing
# ###Parsing----------Page 72 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 73 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=720----------Scraping###
# ###Scraping----------page 73 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=720----------Scraping###
# ###Parsing----------Start parsing page 73----------###Parsing
# ###Parsing----------Page 73 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 74 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=730----------Scraping###
# ###Scraping----------page 74 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=730----------Scraping###
# ###Parsing----------Start parsing page 74----------###Parsing
# ###Parsing----------Page 74 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 75 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=740----------Scraping###
# ###Scraping----------page 75 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=740----------Scraping###
# ###Parsing----------Start parsing page 75----------###Parsing
# ###Parsing----------Page 75 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 76 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=750----------Scraping###
# ###Scraping----------page 76 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=750----------Scraping###
# ###Parsing----------Start parsing page 76----------###Parsing
# ###Parsing----------Page 76 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 77 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=760----------Scraping###
# ###Scraping----------page 77 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=760----------Scraping###
# ###Parsing----------Start parsing page 77----------###Parsing
# ###Parsing----------Page 77 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 78 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=770----------Scraping###
# ###Scraping----------page 78 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=770----------Scraping###
# ###Parsing----------Start parsing page 78----------###Parsing
# ###Parsing----------Page 78 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 79 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=780----------Scraping###
# ###Scraping----------page 79 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=780----------Scraping###
# ###Parsing----------Start parsing page 79----------###Parsing
# ###Parsing----------Page 79 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 80 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=790----------Scraping###
# ###Scraping----------page 80 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=790----------Scraping###
# ###Parsing----------Start parsing page 80----------###Parsing
# ###Parsing----------Page 80 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 81 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=800----------Scraping###
# ###Scraping----------page 81 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=800----------Scraping###
# ###Parsing----------Start parsing page 81----------###Parsing
# ###Parsing----------Page 81 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 82 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=810----------Scraping###
# ###Scraping----------page 82 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=810----------Scraping###
# ###Parsing----------Start parsing page 82----------###Parsing
# ###Parsing----------Page 82 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 83 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=820----------Scraping###
# ###Scraping----------page 83 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=820----------Scraping###
# ###Parsing----------Start parsing page 83----------###Parsing
# ###Parsing----------Page 83 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 84 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=830----------Scraping###
# ###Scraping----------page 84 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=830----------Scraping###
# ###Parsing----------Start parsing page 84----------###Parsing
# ###Parsing----------Page 84 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 85 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=840----------Scraping###
# ###Scraping----------page 85 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=840----------Scraping###
# ###Parsing----------Start parsing page 85----------###Parsing
# ###Parsing----------Page 85 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 86 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=850----------Scraping###
# ###Scraping----------page 86 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=850----------Scraping###
# ###Parsing----------Start parsing page 86----------###Parsing
# ###Parsing----------Page 86 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 87 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=860----------Scraping###
# ###Scraping----------page 87 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=860----------Scraping###
# ###Parsing----------Start parsing page 87----------###Parsing
# ###Parsing----------Page 87 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 88 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=870----------Scraping###
# ###Scraping----------page 88 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=870----------Scraping###
# ###Parsing----------Start parsing page 88----------###Parsing
# ###Parsing----------Page 88 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 89 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=880----------Scraping###
# ###Scraping----------page 89 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=880----------Scraping###
# ###Parsing----------Start parsing page 89----------###Parsing
# ###Parsing----------Page 89 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 90 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=890----------Scraping###
# ###Scraping----------page 90 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=890----------Scraping###
# ###Parsing----------Start parsing page 90----------###Parsing
# ###Parsing----------Page 90 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 91 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=900----------Scraping###
# ###Scraping----------page 91 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=900----------Scraping###
# ###Parsing----------Start parsing page 91----------###Parsing
# ###Parsing----------Page 91 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 92 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=910----------Scraping###
# ###Scraping----------page 92 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=910----------Scraping###
# ###Parsing----------Start parsing page 92----------###Parsing
# ###Parsing----------Page 92 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 93 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=920----------Scraping###
# ###Scraping----------page 93 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=920----------Scraping###
# ###Parsing----------Start parsing page 93----------###Parsing
# ###Parsing----------Page 93 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 94 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=930----------Scraping###
# ###Scraping----------page 94 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=930----------Scraping###
# ###Parsing----------Start parsing page 94----------###Parsing
# ###Parsing----------Page 94 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 95 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=940----------Scraping###
# ###Scraping----------page 95 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=940----------Scraping###
# ###Parsing----------Start parsing page 95----------###Parsing
# ###Parsing----------Page 95 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 96 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=950----------Scraping###
# ###Scraping----------page 96 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=950----------Scraping###
# ###Parsing----------Start parsing page 96----------###Parsing
# ###Parsing----------Page 96 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 97 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=960----------Scraping###
# ###Scraping----------page 97 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=960----------Scraping###
# ###Parsing----------Start parsing page 97----------###Parsing
# ###Parsing----------Page 97 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 98 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=970----------Scraping###
# ###Scraping----------page 98 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=970----------Scraping###
# ###Parsing----------Start parsing page 98----------###Parsing
# ###Parsing----------Page 98 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 99 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=980----------Scraping###
# ###Scraping----------page 99 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=980----------Scraping###
# ###Parsing----------Start parsing page 99----------###Parsing
# ###Parsing----------Page 99 parsed successfully----------###Parsing
# ###Scraping----------Start scraping page 100 from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=990----------Scraping###
# ###Scraping----------page 100 scraped successfully from http://www.indeed.com/jobs?q=&l=Massachusetts&jt=internship&start=990----------Scraping###
# ###Parsing----------Start parsing page 100----------###Parsing
# ###Parsing----------Page 100 parsed successfully----------###Parsing

# %%
write_csv(job_list, 'job_list.csv')

# %%
company_dict = {}
for x in job_list:
    if (x[1] in company_dict):
        continue
    if (x[3] == '#'):
        continue
    company_dict[x[1]] = x[3] + "/reviews"

# %%
rating_map = {"17" : "1", "34" : "2", "51" : "3", "68" : "4", "86" : "5"}

# %%
def get_review_list_page(url):
    
    # Sleep 2 sec before starting a new http request
    time.sleep(2)
    # Request page
    headers = { 'User-Agent' : user_agent }
    response = requests.get(url, headers=headers)
    html = response.text.encode('utf-8')
    # Save the 
    with open(('Indeed_review_list_page.html'), "wb") as h:
        h.write(html)
    return html

# %%
def parse_review_list(html, review_list, company):
    soup = BeautifulSoup(html, 'lxml')
    review_boxes = soup.find_all('div', {'class' : 'cmp-review-container'})
    for review_box in review_boxes:
        if (not review_box):
            break
        rating = review_box.find('span', {'class' : 'cmp-rating-inner rating'})
        rating_value = rating_map[rating['style'][6: 8]]
        name = company
        title = review_box.find('span', {'class' : 'cmp-reviewer'})
        if (not title):
            continue
        else:
            title = title.text
        location = review_box.find('span', {'class' : 'cmp-reviewer-job-location'})
        if (not location):
            continue
        else:
            location = location.text.split(',')[0]
        data = [name, title, location, rating_value]
        review_list.append(data)

# %%
def find_next(html, i):
    soup = BeautifulSoup(html, 'lxml')
    next_page = soup.find('div', {'id' : 'company_reviews_pagination_pair_container'})
    if (i != 2 and next_page is None):
        return False
    return True

# %%
def write_review_list(review_list, file_name):
    with open(file_name, 'wb') as fp:
        wr = csv.writer(fp)
        head = ['Company', 'Title', 'Location', 'Rating']
        wr.writerow(head)
        for x in review_list:
            wr.writerow(x)
    fp.close()

# %%
for key, value in company_dict.items():
    review_list = []
    i = 2
    start_url = site_url + value
    company = key
    company = re.sub("\W", "-", company)
    url = site_url + value
    while (True):
        html = get_review_list_page(url)
        parse_review_list(html, review_list, company)
        if (find_next(html, i)):
            print("### start capturing data from " + url + " ###")
            url = start_url + "?start=" + str(i) + "0"
            i+=1
            if (i > 100):
                break;
        else:
            break
    
    write_review_list(review_list, "Company/" + company + ".csv")
# Out:
# ### start capturing data from http://www.indeed.com/cmp/Tripadvisor/reviews ###
# ### start capturing data from http://www.indeed.com/cmp/Ipswitch,-Inc/reviews ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=20 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=30 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=40 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=50 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=60 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=70 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=80 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=90 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=100 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=110 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=120 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=130 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=140 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=150 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=160 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=170 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=180 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=190 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=200 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=210 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=220 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=230 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=240 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=250 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=260 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=270 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=280 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=290 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=300 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=310 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=320 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=330 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=340 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=350 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=360 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=370 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=380 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=390 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=400 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=410 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=420 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=430 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=440 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=450 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=460 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=470 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=480 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=490 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=500 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=510 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=520 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=530 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=540 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=550 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=560 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=570 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=580 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=590 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=600 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=610 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=620 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=630 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=640 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=650 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=660 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=670 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=680 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=690 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=700 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=710 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=720 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=730 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=740 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=750 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=760 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=770 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=780 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=790 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=800 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=810 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=820 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=830 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=840 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=850 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=860 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=870 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=880 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=890 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=900 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=910 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=920 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=930 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=940 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=950 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=960 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=970 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=980 ###
# ### start capturing data from http://www.indeed.com/cmp/UPS/reviews?start=990 ###
# ### start capturing data from http://www.indeed.com/cmp/Home-Market-Foods,-Inc./reviews ###
# ### start capturing data from http://www.indeed.com/cmp/Covestro/reviews ###
# ### start capturing data from http://www.indeed.com/cmp/Icf/reviews ###
# ### start capturing data from http://www.indeed.com/cmp/Icf/reviews?start=20 ###
# ### start capturing data from http://www.indeed.com/cmp/Icf/reviews?start=30 ###
# ### start capturing data from http://www.indeed.com/cmp/Icf/reviews?start=40 ###
# ### start capturing data from http://www.indeed.com/cmp/Icf/reviews?start=50 ###
# ### start capturing data from http://www.indeed.com/cmp/Icf/reviews?start=60 ###
# ### start capturing data from http://www.indeed.com/cmp/Icf/reviews?start=70 ###
# ### start capturing data from http://www.indeed.com/cmp/Icf/reviews?start=80 ###
# ### start capturing data from http://www.indeed.com/cmp/Icf/reviews?start=90 ###
# ### start capturing data from http://www.indeed.com/cmp/Icf/reviews?start=100 ###
# ### start capturing data from http://www.indeed.com/cmp/Icf/reviews?start=110 ###
# ### start capturing data from http://www.indeed.com/cmp/Icf/reviews?start=120 ###
# ### start capturing data from http://www.indeed.com/cmp/Icf/reviews?start=130 ###
# ### start capturing data from http://www.indeed.com/cmp/Icf/reviews?start=140 ###
# ### start capturing data from http://www.indeed.com/cmp/Icf/reviews?start=150 ###
# ### start capturing data from http://www.indeed.com/cmp/Icf/reviews?start=160 ###
# ### start capturing data from http://www.indeed.com/cmp/Icf/reviews?start=170 ###
# ### start capturing data from http://www.indeed.com/cmp/Icf/reviews?start=180 ###
# ### start capturing data from http://www.indeed.com/cmp/Icf/reviews?start=190 ###
# ### start capturing data from http://www.indeed.com/cmp/Icf/reviews?start=200 ###
# ### start capturing data from http://www.indeed.com/cmp/Icf/reviews?start=210 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=20 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=30 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=40 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=50 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=60 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=70 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=80 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=90 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=100 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=110 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=120 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=130 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=140 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=150 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=160 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=170 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=180 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=190 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=200 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=210 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=220 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=230 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=240 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=250 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=260 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=270 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=280 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=290 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=300 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=310 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=320 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=330 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=340 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=350 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=360 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=370 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=380 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=390 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=400 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=410 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=420 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=430 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=440 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=450 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=460 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=470 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=480 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=490 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=500 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=510 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=520 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=530 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=540 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=550 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=560 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=570 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=580 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=590 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=600 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=610 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=620 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=630 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=640 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=650 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=660 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=670 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=680 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=690 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=700 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=710 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=720 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=730 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=740 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=750 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=760 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=770 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=780 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=790 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=800 ###
# ### start capturing data from http://www.indeed.com/cmp/Bright-Horizons-Family-Solutions/reviews?start=810 ###
# ### start capturing data from http://www.indeed.com/cmp/Silicon-Valley-Bank/reviews ###
# ### start capturing data from http://www.indeed.com/cmp/Synopsys/reviews ###
# ### start capturing data from http://www.indeed.com/cmp/Synopsys/reviews?start=20 ###
# ### start capturing data from http://www.indeed.com/cmp/Synopsys/reviews?start=30 ###
# ### start capturing data from http://www.indeed.com/cmp/Ati/reviews ###
# ### start capturing data from http://www.indeed.com/cmp/Ati/reviews?start=20 ###
# ### start capturing data from http://www.indeed.com/cmp/Ati/reviews?start=30 ###
# ### start capturing data from http://www.indeed.com/cmp/Morpho-Detection/reviews ###
# ### start capturing data from http://www.indeed.com/cmp/Umass-Memorial-Medical-Center/reviews ###
# ### start capturing data from http://www.indeed.com/cmp/Umass-Memorial-Medical-Center/reviews?start=20 ###
# ### start capturing data from http://www.indeed.com/cmp/Umass-Memorial-Medical-Center/reviews?start=30 ###
# ### start capturing data from http://www.indeed.com/cmp/Umass-Memorial-Medical-Center/reviews?start=40 ###
# ### start capturing data from http://www.indeed.com/cmp/Umass-Memorial-Medical-Center/reviews?start=50 ###
# ### start capturing data from http://www.indeed.com/cmp/Umass-Memorial-Medical-Center/reviews?start=60 ###
# ### start capturing data from http://www.indeed.com/cmp/Umass-Memorial-Medical-Center/reviews?start=70 ###
# ### start capturing data from http://www.indeed.com/cmp/Umass-Memorial-Medical-Center/reviews?start=80 ###
# ### start capturing data from http://www.indeed.com/cmp/Umass-Memorial-Medical-Center/reviews?start=90 ###
# ### start capturing data from http://www.indeed.com/cmp/Umass-Memorial-Medical-Center/reviews?start=100 ###
# ### start capturing data from http://www.indeed.com/cmp/Umass-Memorial-Medical-Center/reviews?start=110 ###
# ### start capturing data from http://www.indeed.com/cmp/Umass-Memorial-Medical-Center/reviews?start=120 ###
# ### start capturing data from http://www.indeed.com/cmp/Umass-Memorial-Medical-Center/reviews?start=130 ###
# ### start capturing data from http://www.indeed.com/cmp/Umass-Memorial-Medical-Center/reviews?start=140 ###
# ### start capturing data from http://www.indeed.com/cmp/Umass-Memorial-Medical-Center/reviews?start=150 ###
# ### start capturing data from http://www.indeed.com/cmp/Umass-Memorial-Medical-Center/reviews?start=160 ###
# ### start capturing data from http://www.indeed.com/cmp/Umass-Memorial-Medical-Center/reviews?start=170 ###
# ### start capturing data from http://www.indeed.com/cmp/Umass-Memorial-Medical-Center/reviews?start=180 ###
# ### start capturing data from http://www.indeed.com/cmp/Umass-Memorial-Medical-Center/reviews?start=190 ###
# ### start capturing data from http://www.indeed.com/cmp/Arm/reviews ###
# ### start capturing data from http://www.indeed.com/cmp/Beacon-Press/reviews ###
# ### start capturing data from http://www.indeed.com/cmp/Brafton/reviews ###
# ### start capturing data from http://www.indeed.com/jobs?q=&l=Massachusetts&rbt=Marketing+Intern&rbc=Clean+Bottle&jtid=494ddecd4d672b56&jcid=c04e8fa49ed16767&jt=internship&grp=tcl/reviews ###
# ### start capturing data from http://www.indeed.com/cmp/Amadeus-IT-Group-Sa/reviews ###
# ### start capturing data from http://www.indeed.com/cmp/Follett-Corporation/reviews ###
# ### start capturing data from http://www.indeed.com/cmp/Follett-Corporation/reviews?start=20 ###
# ### start capturing data from http://www.indeed.com/cmp/Follett-Corporation/reviews?start=30 ###
# ### start capturing data from http://www.indeed.com/cmp/Follett-Corporation/reviews?start=40 ###
# ### start capturing data from http://www.indeed.com/cmp/Follett-Corporation/reviews?start=50 ###
# ### start capturing data from http://www.indeed.com/cmp/Follett-Corporation/reviews?start=60 ###
# ### start capturing data from http://www.indeed.com/cmp/Follett-Corporation/reviews?start=70 ###
# ### start capturing data from http://www.indeed.com/cmp/Follett-Corporation/reviews?start=80 ###
# ### start capturing data from http://www.indeed.com/cmp/Follett-Corporation/reviews?start=90 ###
# ### start capturing data from http://www.indeed.com/cmp/Follett-Corporation/reviews?start=100 ###
# ### start capturing data from http://www.indeed.com/cmp/Follett-Corporation/reviews?start=110 ###
# ### start capturing data from http://www.indeed.com/cmp/Follett-Corporation/reviews?start=120 ###
# ### start capturing data from http://www.indeed.com/cmp/Follett-Corporation/reviews?start=130 ###
# ### start capturing data from http://www.indeed.com/cmp/Follett-Corporation/reviews?start=140 ###
# ### start capturing data from http://www.indeed.com/cmp/Follett-Corporation/reviews?start=150 ###
# ### start capturing data from http://www.indeed.com/cmp/Follett-Corporation/reviews?start=160 ###
# ### start capturing data from http://www.indeed.com/cmp/Follett-Corporation/reviews?start=170 ###
# ### start capturing data from http://www.indeed.com/cmp/Follett-Corporation/reviews?start=180 ###
# ### start capturing data from http://www.indeed.com/cmp/Follett-Corporation/reviews?start=190 ###
# ### start capturing data from http://www.indeed.com/cmp/Follett-Corporation/reviews?start=200 ###
# ### start capturing data from http://www.indeed.com/cmp/Follett-Corporation/reviews?start=210 ###
# ### start capturing data from http://www.indeed.com/cmp/Follett-Corporation/reviews?start=220 ###
# ### start capturing data from http://www.indeed.com/cmp/Follett-Corporation/reviews?start=230 ###
# ### start capturing data from http://www.indeed.com/cmp/Follett-Corporation/reviews?start=240 ###
# ### start capturing data from http://www.indeed.com/cmp/Follett-Corporation/reviews?start=250 ###
# ### start capturing data from http://www.indeed.com/cmp/Follett-Corporation/reviews?start=260 ###
# ### start capturing data from http://www.indeed.com/cmp/Follett-Corporation/reviews?start=270 ###
# ### start capturing data from http://www.indeed.com/cmp/Follett-Corporation/reviews?start=280 ###
# ### start capturing data from http://www.indeed.com/cmp/Follett-Corporation/reviews?start=290 ###
# ### start capturing data from http://www.indeed.com/cmp/Follett-Corporation/reviews?start=300 ###
# ### start capturing data from http://www.indeed.com/cmp/Follett-Corporation/reviews?start=310 ###
# ### start capturing data from http://www.indeed.com/cmp/Follett-Corporation/reviews?start=320 ###
# ### start capturing data from http://www.indeed.com/cmp/Follett-Corporation/reviews?start=330 ###
# ### start capturing data from http://www.indeed.com/cmp/Follett-Corporation/reviews?start=340 ###
# ### start capturing data from http://www.indeed.com/cmp/Follett-Corporation/reviews?start=350 ###
# ### start capturing data from http://www.indeed.com/cmp/Follett-Corporation/reviews?start=360 ###
# ### start capturing data from http://www.indeed.com/cmp/Follett-Corporation/reviews?start=370 ###
# ### start capturing data from http://www.indeed.com/cmp/Follett-Corporation/reviews?start=380 ###
# ### start capturing data from http://www.indeed.com/cmp/Follett-Corporation/reviews?start=390 ###
# ### start capturing data from http://www.indeed.com/cmp/Follett-Corporation/reviews?start=400 ###
# ### start capturing data from http://www.indeed.com/cmp/Follett-Corporation/reviews?start=410 ###
# ### start capturing data from http://www.indeed.com/cmp/Follett-Corporation/reviews?start=420 ###
# ### start capturing data from http://www.indeed.com/cmp/Follett-Corporation/reviews?start=430 ###
# ### start capturing data from http://www.indeed.com/cmp/Carbonite/reviews ###
# ### start capturing data from http://www.indeed.com/cmp/Virgin-Pulse/reviews ###
# ### start capturing data from http://www.indeed.com/cmp/Unifirst/reviews ###
# ### start capturing data from http://www.indeed.com/cmp/Unifirst/reviews?start=20 ###
# ### start capturing data from http://www.indeed.com/cmp/Unifirst/reviews?start=30 ###
# ### start capturing data from http://www.indeed.com/cmp/Unifirst/reviews?start=40 ###
# ### start capturing data from http://www.indeed.com/cmp/Unifirst/reviews?start=50 ###
# ### start capturing data from http://www.indeed.com/cmp/Unifirst/reviews?start=60 ###
# ### start capturing data from http://www.indeed.com/cmp/Unifirst/reviews?start=70 ###
# ### start capturing data from http://www.indeed.com/cmp/Unifirst/reviews?start=80 ###
# ### start capturing data from http://www.indeed.com/cmp/Unifirst/reviews?start=90 ###
# ### start capturing data from http://www.indeed.com/cmp/Unifirst/reviews?start=100 ###
# ### start capturing data from http://www.indeed.com/cmp/Unifirst/reviews?start=110 ###
# ### start capturing data from http://www.indeed.com/cmp/Unifirst/reviews?start=120 ###
# ### start capturing data from http://www.indeed.com/cmp/Unifirst/reviews?start=130 ###
# ### start capturing data from http://www.indeed.com/cmp/Unifirst/reviews?start=140 ###
# ### start capturing data from http://www.indeed.com/cmp/Unifirst/reviews?start=150 ###
# ### start capturing data from http://www.indeed.com/cmp/Unifirst/reviews?start=160 ###
# ### start capturing data from http://www.indeed.com/cmp/Unifirst/reviews?start=170 ###
# ### start capturing data from http://www.indeed.com/cmp/Unifirst/reviews?start=180 ###
# ### start capturing data from http://www.indeed.com/cmp/Unifirst/reviews?start=190 ###
# ### start capturing data from http://www.indeed.com/cmp/Unifirst/reviews?start=200 ###
# ### start capturing data from http://www.indeed.com/cmp/Unifirst/reviews?start=210 ###
# ### start capturing data from http://www.indeed.com/cmp/Unifirst/reviews?start=220 ###
# ### start capturing data from http://www.indeed.com/cmp/Unifirst/reviews?start=230 ###
# ### start capturing data from http://www.indeed.com/cmp/Unifirst/reviews?start=240 ###
# ### start capturing data from http://www.indeed.com/cmp/Unifirst/reviews?start=250 ###
# ### start capturing data from http://www.indeed.com/cmp/Unifirst/reviews?start=260 ###
# ### start capturing data from http://www.indeed.com/cmp/Unifirst/reviews?start=270 ###
# ### start capturing data from http://www.indeed.com/cmp/Unifirst/reviews?start=280 ###
# ### start capturing data from http://www.indeed.com/cmp/Unifirst/reviews?start=290 ###
# ### start capturing data from http://www.indeed.com/cmp/Unifirst/reviews?start=300 ###
# ### start capturing data from http://www.indeed.com/cmp/Unifirst/reviews?start=310 ###
# ### start capturing data from http://www.indeed.com/cmp/Unifirst/reviews?start=320 ###
# ### start capturing data from http://www.indeed.com/cmp/Unifirst/reviews?start=330 ###
# ### start capturing data from http://www.indeed.com/cmp/Unifirst/reviews?start=340 ###
# ### start capturing data from http://www.indeed.com/cmp/Unifirst/reviews?start=350 ###
# ### start capturing data from http://www.indeed.com/cmp/Unifirst/reviews?start=360 ###
# ### start capturing data from http://www.indeed.com/cmp/Unifirst/reviews?start=370 ###
# ### start capturing data from http://www.indeed.com/cmp/Unifirst/reviews?start=380 ###
# ### start capturing data from http://www.indeed.com/cmp/Unifirst/reviews?start=390 ###
# ### start capturing data from http://www.indeed.com/cmp/Unifirst/reviews?start=400 ###
# ### start capturing data from http://www.indeed.com/cmp/Unifirst/reviews?start=410 ###
# ### start capturing data from http://www.indeed.com/cmp/Unifirst/reviews?start=420 ###
# ### start capturing data from http://www.indeed.com/cmp/Unifirst/reviews?start=430 ###
# ### start capturing data from http://www.indeed.com/cmp/Unifirst/reviews?start=440 ###
# ### start capturing data from http://www.indeed.com/cmp/Unifirst/reviews?start=450 ###
# ### start capturing data from http://www.indeed.com/cmp/The-Mathworks/reviews ###
# ### start capturing data from http://www.indeed.com/cmp/Demandware/reviews ###
# ### start capturing data from http://www.indeed.com/cmp/Ptc/reviews ###
# ### start capturing data from http://www.indeed.com/cmp/Ptc/reviews?start=20 ###
# ### start capturing data from http://www.indeed.com/cmp/Ptc/reviews?start=30 ###
# ### start capturing data from http://www.indeed.com/cmp/Ptc/reviews?start=40 ###
# ### start capturing data from http://www.indeed.com/cmp/Ptc/reviews?start=50 ###
# ### start capturing data from http://www.indeed.com/cmp/The-Kraft-Group/reviews ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=20 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=30 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=40 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=50 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=60 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=70 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=80 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=90 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=100 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=110 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=120 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=130 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=140 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=150 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=160 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=170 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=180 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=190 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=200 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=210 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=220 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=230 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=240 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=250 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=260 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=270 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=280 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=290 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=300 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=310 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=320 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=330 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=340 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=350 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=360 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=370 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=380 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=390 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=400 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=410 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=420 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=430 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=440 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=450 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=460 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=470 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=480 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=490 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=500 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=510 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=520 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=530 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=540 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=550 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=560 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=570 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=580 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=590 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=600 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=610 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=620 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=630 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=640 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=650 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=660 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=670 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=680 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=690 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=700 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=710 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=720 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=730 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=740 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=750 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=760 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=770 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=780 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=790 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=800 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=810 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=820 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=830 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=840 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=850 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=860 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=870 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=880 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=890 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=900 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=910 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=920 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=930 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=940 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=950 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=960 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=970 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=980 ###
# ### start capturing data from http://www.indeed.com/cmp/Raytheon/reviews?start=990 ###
# ### start capturing data from http://www.indeed.com/cmp/Planned-Parenthood/reviews ###
# ### start capturing data from http://www.indeed.com/cmp/Planned-Parenthood/reviews?start=20 ###
# ### start capturing data from http://www.indeed.com/cmp/Planned-Parenthood/reviews?start=30 ###
# ### start capturing data from http://www.indeed.com/cmp/Planned-Parenthood/reviews?start=40 ###
# ### start capturing data from http://www.indeed.com/cmp/Planned-Parenthood/reviews?start=50 ###
# ### start capturing data from http://www.indeed.com/cmp/Planned-Parenthood/reviews?start=60 ###
# ### start capturing data from http://www.indeed.com/cmp/Planned-Parenthood/reviews?start=70 ###
# ### start capturing data from http://www.indeed.com/cmp/Planned-Parenthood/reviews?start=80 ###
# ### start capturing data from http://www.indeed.com/cmp/Planned-Parenthood/reviews?start=90 ###
# ### start capturing data from http://www.indeed.com/cmp/Planned-Parenthood/reviews?start=100 ###
# ### start capturing data from http://www.indeed.com/cmp/Planned-Parenthood/reviews?start=110 ###
# ### start capturing data from http://www.indeed.com/cmp/Planned-Parenthood/reviews?start=120 ###
# ### start capturing data from http://www.indeed.com/cmp/Planned-Parenthood/reviews?start=130 ###
# ### start capturing data from http://www.indeed.com/cmp/Planned-Parenthood/reviews?start=140 ###
# ### start capturing data from http://www.indeed.com/cmp/Planned-Parenthood/reviews?start=150 ###
# ### start capturing data from http://www.indeed.com/cmp/Planned-Parenthood/reviews?start=160 ###
# ### start capturing data from http://www.indeed.com/cmp/Planned-Parenthood/reviews?start=170 ###
# ### start capturing data from http://www.indeed.com/cmp/Planned-Parenthood/reviews?start=180 ###
# ### start capturing data from http://www.indeed.com/cmp/Planned-Parenthood/reviews?start=190 ###
# ### start capturing data from http://www.indeed.com/cmp/Planned-Parenthood/reviews?start=200 ###
# ### start capturing data from http://www.indeed.com/cmp/Planned-Parenthood/reviews?start=210 ###
# ### start capturing data from http://www.indeed.com/cmp/Planned-Parenthood/reviews?start=220 ###
# ### start capturing data from http://www.indeed.com/cmp/Planned-Parenthood/reviews?start=230 ###
# ### start capturing data from http://www.indeed.com/cmp/Planned-Parenthood/reviews?start=240 ###
# ### start capturing data from http://www.indeed.com/cmp/Planned-Parenthood/reviews?start=250 ###
# ### start capturing data from http://www.indeed.com/cmp/Planned-Parenthood/reviews?start=260 ###
# ### start capturing data from http://www.indeed.com/cmp/Planned-Parenthood/reviews?start=270 ###
# ### start capturing data from http://www.indeed.com/cmp/Planned-Parenthood/reviews?start=280 ###
# ### start capturing data from http://www.indeed.com/cmp/Planned-Parenthood/reviews?start=290 ###
# ### start capturing data from http://www.indeed.com/cmp/Planned-Parenthood/reviews?start=300 ###
# ### start capturing data from http://www.indeed.com/cmp/Planned-Parenthood/reviews?start=310 ###
# ### start capturing data from http://www.indeed.com/cmp/Planned-Parenthood/reviews?start=320 ###
# ### start capturing data from http://www.indeed.com/cmp/Planned-Parenthood/reviews?start=330 ###
# ### start capturing data from http://www.indeed.com/cmp/Planned-Parenthood/reviews?start=340 ###
# ### start capturing data from http://www.indeed.com/cmp/Planned-Parenthood/reviews?start=350 ###
# ### start capturing data from http://www.indeed.com/cmp/Planned-Parenthood/reviews?start=360 ###
# ### start capturing data from http://www.indeed.com/cmp/Planned-Parenthood/reviews?start=370 ###
# ### start capturing data from http://www.indeed.com/cmp/Planned-Parenthood/reviews?start=380 ###
# ### start capturing data from http://www.indeed.com/cmp/Planned-Parenthood/reviews?start=390 ###
# ### start capturing data from http://www.indeed.com/cmp/Planned-Parenthood/reviews?start=400 ###
# ### start capturing data from http://www.indeed.com/cmp/Planned-Parenthood/reviews?start=410 ###
# ### start capturing data from http://www.indeed.com/cmp/Planned-Parenthood/reviews?start=420 ###
# ### start capturing data from http://www.indeed.com/cmp/Planned-Parenthood/reviews?start=430 ###
# ### start capturing data from http://www.indeed.com/cmp/Planned-Parenthood/reviews?start=440 ###
# ### start capturing data from http://www.indeed.com/cmp/Planned-Parenthood/reviews?start=450 ###
# ### start capturing data from http://www.indeed.com/cmp/Planned-Parenthood/reviews?start=460 ###
# ### start capturing data from http://www.indeed.com/cmp/Planned-Parenthood/reviews?start=470 ###
# ### start capturing data from http://www.indeed.com/cmp/Planned-Parenthood/reviews?start=480 ###
# ### start capturing data from http://www.indeed.com/cmp/Planned-Parenthood/reviews?start=490 ###
# ### start capturing data from http://www.indeed.com/cmp/Planned-Parenthood/reviews?start=500 ###
# ### start capturing data from http://www.indeed.com/cmp/Planned-Parenthood/reviews?start=510 ###
# ### start capturing data from http://www.indeed.com/cmp/Planned-Parenthood/reviews?start=520 ###
# ### start capturing data from http://www.indeed.com/cmp/Planned-Parenthood/reviews?start=530 ###
# ### start capturing data from http://www.indeed.com/cmp/Planned-Parenthood/reviews?start=540 ###
# ### start capturing data from http://www.indeed.com/cmp/Planned-Parenthood/reviews?start=550 ###
# ### start capturing data from http://www.indeed.com/cmp/Planned-Parenthood/reviews?start=560 ###
# ### start capturing data from http://www.indeed.com/cmp/Planned-Parenthood/reviews?start=570 ###
# ### start capturing data from http://www.indeed.com/cmp/Planned-Parenthood/reviews?start=580 ###
# ### start capturing data from http://www.indeed.com/cmp/Planned-Parenthood/reviews?start=590 ###
# ### start capturing data from http://www.indeed.com/cmp/Planned-Parenthood/reviews?start=600 ###
# ### start capturing data from http://www.indeed.com/cmp/Planned-Parenthood/reviews?start=610 ###
# ### start capturing data from http://www.indeed.com/cmp/Planned-Parenthood/reviews?start=620 ###
# ### start capturing data from http://www.indeed.com/cmp/Planned-Parenthood/reviews?start=630 ###
# ### start capturing data from http://www.indeed.com/cmp/Planned-Parenthood/reviews?start=640 ###
# ### start capturing data from http://www.indeed.com/cmp/Planned-Parenthood/reviews?start=650 ###
# ### start capturing data from http://www.indeed.com/cmp/Air-Worldwide/reviews ###
# ### start capturing data from http://www.indeed.com/cmp/Perkinelmer/reviews ###
# ### start capturing data from http://www.indeed.com/cmp/Perkinelmer/reviews?start=20 ###
# ### start capturing data from http://www.indeed.com/cmp/Perkinelmer/reviews?start=30 ###
# ### start capturing data from http://www.indeed.com/cmp/Perkinelmer/reviews?start=40 ###
# ### start capturing data from http://www.indeed.com/cmp/Perkinelmer/reviews?start=50 ###
# ### start capturing data from http://www.indeed.com/cmp/Perkinelmer/reviews?start=60 ###
# ### start capturing data from http://www.indeed.com/cmp/Perkinelmer/reviews?start=70 ###
# ### start capturing data from http://www.indeed.com/cmp/Perkinelmer/reviews?start=80 ###
# ### start capturing data from http://www.indeed.com/cmp/Perkinelmer/reviews?start=90 ###
# ### start capturing data from http://www.indeed.com/cmp/Onebeacon-Insurance-Group/reviews ###
# ### start capturing data from http://www.indeed.com/cmp/Wsp-Parsons-Brinckerhoff/reviews ###
# ### start capturing data from http://www.indeed.com/cmp/You-Inc/reviews ###
# ### start capturing data from http://www.indeed.com/cmp/Horizons-For-Homeless-Children/reviews ###
# ### start capturing data from http://www.indeed.com/cmp/Merck/reviews ###
# ### start capturing data from http://www.indeed.com/cmp/Merck/reviews?start=20 ###
# ### start capturing data from http://www.indeed.com/cmp/Merck/reviews?start=30 ###
# ### start capturing data from http://www.indeed.com/cmp/Merck/reviews?start=40 ###
# ### start capturing data from http://www.indeed.com/cmp/Merck/reviews?start=50 ###
# ### start capturing data from http://www.indeed.com/cmp/Merck/reviews?start=60 ###
# ### start capturing data from http://www.indeed.com/cmp/Merck/reviews?start=70 ###
# ### start capturing data from http://www.indeed.com/cmp/Merck/reviews?start=80 ###
# ...
# ### start capturing data from http://www.indeed.com/cmp/Liberty-Mutual/reviews?start=910 ###
# ### start capturing data from http://www.indeed.com/cmp/Liberty-Mutual/reviews?start=920 ###
# ### start capturing data from http://www.indeed.com/cmp/Liberty-Mutual/reviews?start=930 ###
# ### start capturing data from http://www.indeed.com/cmp/Liberty-Mutual/reviews?start=940 ###
# ### start capturing data from http://www.indeed.com/cmp/Liberty-Mutual/reviews?start=950 ###
# ### start capturing data from http://www.indeed.com/cmp/Liberty-Mutual/reviews?start=960 ###
# ### start capturing data from http://www.indeed.com/cmp/Liberty-Mutual/reviews?start=970 ###
# ### start capturing data from http://www.indeed.com/cmp/Liberty-Mutual/reviews?start=980 ###
# ### start capturing data from http://www.indeed.com/cmp/Liberty-Mutual/reviews?start=990 ###
# ### start capturing data from http://www.indeed.com/cmp/Nesn/reviews ###
# ### start capturing data from http://www.indeed.com/cmp/Federal-Reserve-Bank-of-New-York/reviews ###
# ### start capturing data from http://www.indeed.com/cmp/Federal-Reserve-Bank-of-New-York/reviews?start=20 ###
# ### start capturing data from http://www.indeed.com/cmp/Federal-Reserve-Bank-of-New-York/reviews?start=30 ###
# ### start capturing data from http://www.indeed.com/cmp/Federal-Reserve-Bank-of-New-York/reviews?start=40 ###
# ### start capturing data from http://www.indeed.com/cmp/Federal-Reserve-Bank-of-New-York/reviews?start=50 ###
# ### start capturing data from http://www.indeed.com/cmp/Federal-Reserve-Bank-of-New-York/reviews?start=60 ###
# ### start capturing data from http://www.indeed.com/cmp/Federal-Reserve-Bank-of-New-York/reviews?start=70 ###
# ### start capturing data from http://www.indeed.com/cmp/Federal-Reserve-Bank-of-New-York/reviews?start=80 ###
# ### start capturing data from http://www.indeed.com/cmp/Federal-Reserve-Bank-of-New-York/reviews?start=90 ###
# ### start capturing data from http://www.indeed.com/cmp/Federal-Reserve-Bank-of-New-York/reviews?start=100 ###
# ### start capturing data from http://www.indeed.com/cmp/Federal-Reserve-Bank-of-New-York/reviews?start=110 ###
# ### start capturing data from http://www.indeed.com/cmp/Federal-Reserve-Bank-of-New-York/reviews?start=120 ###
# ### start capturing data from http://www.indeed.com/cmp/Federal-Reserve-Bank-of-New-York/reviews?start=130 ###
# ### start capturing data from http://www.indeed.com/cmp/Federal-Reserve-Bank-of-New-York/reviews?start=140 ###
# ### start capturing data from http://www.indeed.com/cmp/Federal-Reserve-Bank-of-New-York/reviews?start=150 ###
# ### start capturing data from http://www.indeed.com/cmp/Federal-Reserve-Bank-of-New-York/reviews?start=160 ###
# ### start capturing data from http://www.indeed.com/cmp/Federal-Reserve-Bank-of-New-York/reviews?start=170 ###
# ### start capturing data from http://www.indeed.com/cmp/Federal-Reserve-Bank-of-New-York/reviews?start=180 ###
# ### start capturing data from http://www.indeed.com/cmp/Federal-Reserve-Bank-of-New-York/reviews?start=190 ###
# ### start capturing data from http://www.indeed.com/cmp/Federal-Reserve-Bank-of-New-York/reviews?start=200 ###
# ### start capturing data from http://www.indeed.com/cmp/Federal-Reserve-Bank-of-New-York/reviews?start=210 ###
# ### start capturing data from http://www.indeed.com/cmp/Federal-Reserve-Bank-of-New-York/reviews?start=220 ###
# ### start capturing data from http://www.indeed.com/cmp/Federal-Reserve-Bank-of-New-York/reviews?start=230 ###
# ### start capturing data from http://www.indeed.com/cmp/Federal-Reserve-Bank-of-New-York/reviews?start=240 ###
# ### start capturing data from http://www.indeed.com/cmp/Federal-Reserve-Bank-of-New-York/reviews?start=250 ###
# ### start capturing data from http://www.indeed.com/cmp/Federal-Reserve-Bank-of-New-York/reviews?start=260 ###
# ### start capturing data from http://www.indeed.com/cmp/Federal-Reserve-Bank-of-New-York/reviews?start=270 ###
# ### start capturing data from http://www.indeed.com/cmp/Federal-Reserve-Bank-of-New-York/reviews?start=280 ###
# ### start capturing data from http://www.indeed.com/cmp/Federal-Reserve-Bank-of-New-York/reviews?start=290 ###
# ### start capturing data from http://www.indeed.com/cmp/Cme-Group/reviews ###
# ### start capturing data from http://www.indeed.com/cmp/Cme-Group/reviews?start=20 ###
# ### start capturing data from http://www.indeed.com/cmp/Cme-Group/reviews?start=30 ###
# ### start capturing data from http://www.indeed.com/cmp/Cme-Group/reviews?start=40 ###
# ### start capturing data from http://www.indeed.com/cmp/Cme-Group/reviews?start=50 ###
# ### start capturing data from http://www.indeed.com/cmp/Cme-Group/reviews?start=60 ###
# ### start capturing data from http://www.indeed.com/cmp/Cme-Group/reviews?start=70 ###
# ### start capturing data from http://www.indeed.com/cmp/Kronos/reviews ###
# ### start capturing data from http://www.indeed.com/cmp/Kronos/reviews?start=20 ###
# ### start capturing data from http://www.indeed.com/cmp/Kronos/reviews?start=30 ###
# ### start capturing data from http://www.indeed.com/cmp/Netsuite/reviews ###
# ### start capturing data from http://www.indeed.com/cmp/Mitre-Corporation/reviews ###
# ### start capturing data from http://www.indeed.com/cmp/Mitre-Corporation/reviews?start=20 ###
# ### start capturing data from http://www.indeed.com/cmp/Mitre-Corporation/reviews?start=30 ###
# ### start capturing data from http://www.indeed.com/cmp/Mitre-Corporation/reviews?start=40 ###
# ### start capturing data from http://www.indeed.com/cmp/Mitre-Corporation/reviews?start=50 ###
# ### start capturing data from http://www.indeed.com/cmp/Mitre-Corporation/reviews?start=60 ###
# ### start capturing data from http://www.indeed.com/cmp/Mitre-Corporation/reviews?start=70 ###
# ### start capturing data from http://www.indeed.com/cmp/Kayak/reviews ###
# ### start capturing data from http://www.indeed.com/cmp/Stantec-Consulting/reviews ###
# ### start capturing data from http://www.indeed.com/cmp/Stantec-Consulting/reviews?start=20 ###
# ### start capturing data from http://www.indeed.com/cmp/Stantec-Consulting/reviews?start=30 ###
# ### start capturing data from http://www.indeed.com/cmp/Stantec-Consulting/reviews?start=40 ###
# ### start capturing data from http://www.indeed.com/cmp/Stantec-Consulting/reviews?start=50 ###
# ### start capturing data from http://www.indeed.com/cmp/Stantec-Consulting/reviews?start=60 ###
# ### start capturing data from http://www.indeed.com/cmp/Stantec-Consulting/reviews?start=70 ###
# ### start capturing data from http://www.indeed.com/cmp/Stantec-Consulting/reviews?start=80 ###
# ### start capturing data from http://www.indeed.com/cmp/Stantec-Consulting/reviews?start=90 ###
# ### start capturing data from http://www.indeed.com/cmp/University-of-Massachusetts/reviews ###
# ### start capturing data from http://www.indeed.com/cmp/University-of-Massachusetts/reviews?start=20 ###
# ### start capturing data from http://www.indeed.com/cmp/University-of-Massachusetts/reviews?start=30 ###
# ### start capturing data from http://www.indeed.com/cmp/University-of-Massachusetts/reviews?start=40 ###
# ### start capturing data from http://www.indeed.com/cmp/University-of-Massachusetts/reviews?start=50 ###
# ### start capturing data from http://www.indeed.com/cmp/University-of-Massachusetts/reviews?start=60 ###
# ### start capturing data from http://www.indeed.com/cmp/University-of-Massachusetts/reviews?start=70 ###
# ### start capturing data from http://www.indeed.com/cmp/University-of-Massachusetts/reviews?start=80 ###
# ### start capturing data from http://www.indeed.com/cmp/University-of-Massachusetts/reviews?start=90 ###
# ### start capturing data from http://www.indeed.com/cmp/University-of-Massachusetts/reviews?start=100 ###
# ### start capturing data from http://www.indeed.com/cmp/University-of-Massachusetts/reviews?start=110 ###
# ### start capturing data from http://www.indeed.com/cmp/University-of-Massachusetts/reviews?start=120 ###
# ### start capturing data from http://www.indeed.com/cmp/University-of-Massachusetts/reviews?start=130 ###
# ### start capturing data from http://www.indeed.com/cmp/Westinghouse-Electric-Company,-LLC/reviews ###
# ### start capturing data from http://www.indeed.com/cmp/Westinghouse-Electric-Company,-LLC/reviews?start=20 ###
# ### start capturing data from http://www.indeed.com/cmp/Westinghouse-Electric-Company,-LLC/reviews?start=30 ###
# ### start capturing data from http://www.indeed.com/cmp/Westinghouse-Electric-Company,-LLC/reviews?start=40 ###
# ### start capturing data from http://www.indeed.com/cmp/Westinghouse-Electric-Company,-LLC/reviews?start=50 ###
# ### start capturing data from http://www.indeed.com/cmp/Westinghouse-Electric-Company,-LLC/reviews?start=60 ###
# ### start capturing data from http://www.indeed.com/cmp/Westinghouse-Electric-Company,-LLC/reviews?start=70 ###
# ### start capturing data from http://www.indeed.com/cmp/Westinghouse-Electric-Company,-LLC/reviews?start=80 ###
# ### start capturing data from http://www.indeed.com/cmp/Westinghouse-Electric-Company,-LLC/reviews?start=90 ###
# ### start capturing data from http://www.indeed.com/cmp/Westinghouse-Electric-Company,-LLC/reviews?start=100 ###
# ### start capturing data from http://www.indeed.com/cmp/Westinghouse-Electric-Company,-LLC/reviews?start=110 ###
# ### start capturing data from http://www.indeed.com/cmp/Westinghouse-Electric-Company,-LLC/reviews?start=120 ###
# ### start capturing data from http://www.indeed.com/cmp/Westinghouse-Electric-Company,-LLC/reviews?start=130 ###
# ### start capturing data from http://www.indeed.com/cmp/Westinghouse-Electric-Company,-LLC/reviews?start=140 ###
# ### start capturing data from http://www.indeed.com/cmp/Westinghouse-Electric-Company,-LLC/reviews?start=150 ###
# ### start capturing data from http://www.indeed.com/cmp/Westinghouse-Electric-Company,-LLC/reviews?start=160 ###
# ### start capturing data from http://www.indeed.com/cmp/Westinghouse-Electric-Company,-LLC/reviews?start=170 ###
# ### start capturing data from http://www.indeed.com/cmp/Westinghouse-Electric-Company,-LLC/reviews?start=180 ###
# ### start capturing data from http://www.indeed.com/cmp/Westinghouse-Electric-Company,-LLC/reviews?start=190 ###
# ### start capturing data from http://www.indeed.com/cmp/Westinghouse-Electric-Company,-LLC/reviews?start=200 ###
# ### start capturing data from http://www.indeed.com/cmp/Westinghouse-Electric-Company,-LLC/reviews?start=210 ###
# ### start capturing data from http://www.indeed.com/cmp/Ccmsi/reviews ###
# ### start capturing data from http://www.indeed.com/cmp/Agero,-Inc./reviews ###
# ### start capturing data from http://www.indeed.com/cmp/New-England-Aquarium/reviews ###
# ### start capturing data from http://www.indeed.com/cmp/Dassault-Syst%C3%A8mes-1/reviews ###
# ### start capturing data from http://www.indeed.com/cmp/Boston-Children's-Hospital/reviews ###
# ### start capturing data from http://www.indeed.com/cmp/Boston-Children's-Hospital/reviews?start=20 ###
# ### start capturing data from http://www.indeed.com/cmp/Boston-Children's-Hospital/reviews?start=30 ###
# ### start capturing data from http://www.indeed.com/cmp/Boston-Children's-Hospital/reviews?start=40 ###
# ### start capturing data from http://www.indeed.com/cmp/Boston-Children's-Hospital/reviews?start=50 ###
# ### start capturing data from http://www.indeed.com/cmp/Boston-Children's-Hospital/reviews?start=60 ###
# ### start capturing data from http://www.indeed.com/cmp/Boston-Children's-Hospital/reviews?start=70 ###
# ### start capturing data from http://www.indeed.com/cmp/Boston-Children's-Hospital/reviews?start=80 ###
# ### start capturing data from http://www.indeed.com/cmp/Boston-Children's-Hospital/reviews?start=90 ###
# ### start capturing data from http://www.indeed.com/cmp/Boston-Children's-Hospital/reviews?start=100 ###
# ### start capturing data from http://www.indeed.com/cmp/Boston-Children's-Hospital/reviews?start=110 ###
# ### start capturing data from http://www.indeed.com/cmp/Boston-Children's-Hospital/reviews?start=120 ###
# ### start capturing data from http://www.indeed.com/cmp/Boston-Children's-Hospital/reviews?start=130 ###
# ### start capturing data from http://www.indeed.com/cmp/Boston-Children's-Hospital/reviews?start=140 ###
# ### start capturing data from http://www.indeed.com/cmp/Boston-Children's-Hospital/reviews?start=150 ###
# ### start capturing data from http://www.indeed.com/cmp/Corning/reviews ###
# ### start capturing data from http://www.indeed.com/cmp/Corning/reviews?start=20 ###
# ### start capturing data from http://www.indeed.com/cmp/Corning/reviews?start=30 ###
# ### start capturing data from http://www.indeed.com/cmp/Corning/reviews?start=40 ###
# ### start capturing data from http://www.indeed.com/cmp/Corning/reviews?start=50 ###
# ### start capturing data from http://www.indeed.com/cmp/Corning/reviews?start=60 ###
# ### start capturing data from http://www.indeed.com/cmp/Corning/reviews?start=70 ###
# ### start capturing data from http://www.indeed.com/cmp/Corning/reviews?start=80 ###
# ### start capturing data from http://www.indeed.com/cmp/Corning/reviews?start=90 ###
# ### start capturing data from http://www.indeed.com/cmp/Corning/reviews?start=100 ###
# ### start capturing data from http://www.indeed.com/cmp/Corning/reviews?start=110 ###
# ### start capturing data from http://www.indeed.com/cmp/Corning/reviews?start=120 ###
# ### start capturing data from http://www.indeed.com/cmp/Corning/reviews?start=130 ###
# ### start capturing data from http://www.indeed.com/cmp/Corning/reviews?start=140 ###
# ### start capturing data from http://www.indeed.com/cmp/Corning/reviews?start=150 ###
# ### start capturing data from http://www.indeed.com/cmp/Corning/reviews?start=160 ###
# ### start capturing data from http://www.indeed.com/cmp/Corning/reviews?start=170 ###
# ### start capturing data from http://www.indeed.com/cmp/Corning/reviews?start=180 ###
# ### start capturing data from http://www.indeed.com/cmp/Corning/reviews?start=190 ###
# ### start capturing data from http://www.indeed.com/cmp/Avalonbay-Communities/reviews ###
# ### start capturing data from http://www.indeed.com/cmp/Avalonbay-Communities/reviews?start=20 ###
# ### start capturing data from http://www.indeed.com/cmp/Avalonbay-Communities/reviews?start=30 ###
# ### start capturing data from http://www.indeed.com/cmp/Avalonbay-Communities/reviews?start=40 ###
# ### start capturing data from http://www.indeed.com/cmp/Avalonbay-Communities/reviews?start=50 ###
# ### start capturing data from http://www.indeed.com/cmp/Avalonbay-Communities/reviews?start=60 ###
# ### start capturing data from http://www.indeed.com/cmp/Avalonbay-Communities/reviews?start=70 ###
# ### start capturing data from http://www.indeed.com/cmp/Avalonbay-Communities/reviews?start=80 ###
# ### start capturing data from http://www.indeed.com/cmp/Avalonbay-Communities/reviews?start=90 ###
# ### start capturing data from http://www.indeed.com/cmp/Avalonbay-Communities/reviews?start=100 ###
# ### start capturing data from http://www.indeed.com/cmp/Avalonbay-Communities/reviews?start=110 ###
# ### start capturing data from http://www.indeed.com/cmp/Avalonbay-Communities/reviews?start=120 ###
# ### start capturing data from http://www.indeed.com/cmp/Avalonbay-Communities/reviews?start=130 ###
# ### start capturing data from http://www.indeed.com/cmp/Land-O'-Lakes/reviews ###
# ### start capturing data from http://www.indeed.com/cmp/Land-O'-Lakes/reviews?start=20 ###
# ### start capturing data from http://www.indeed.com/cmp/Land-O'-Lakes/reviews?start=30 ###
# ### start capturing data from http://www.indeed.com/cmp/Land-O'-Lakes/reviews?start=40 ###
# ### start capturing data from http://www.indeed.com/cmp/Land-O'-Lakes/reviews?start=50 ###
# ### start capturing data from http://www.indeed.com/cmp/Land-O'-Lakes/reviews?start=60 ###
# ### start capturing data from http://www.indeed.com/cmp/Land-O'-Lakes/reviews?start=70 ###
# ### start capturing data from http://www.indeed.com/cmp/Gilbane/reviews ###
# ### start capturing data from http://www.indeed.com/cmp/Gilbane/reviews?start=20 ###
# ### start capturing data from http://www.indeed.com/cmp/Gilbane/reviews?start=30 ###

# %%
import csv
def run():
    data = merge_companies_info()
    write_data('Merged_Company_Information.csv', data)
    data = train_missing_data()
    write_data("Trained_Company_Data.csv", data)
run()
